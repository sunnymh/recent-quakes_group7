# %% [markdown]
# # Recent Earthquakes: Group 7

# %% [markdown]
# ## Division of work:

# %% [markdown]
# He Ma: data curation
# Carl Shan: data visualization and presentation
# Alyssa Parker: analysis
# Vincent Canlas: analysis

# %% [markdown]
# ## Part 0: User Input:

# %% [markdown]
# **This section is for user configuration:**
# **Please check they are correct before running the code**

# %%
# Decide whether to use live data or read from file. Modify 2nd and 3rd cell accordingly.
LIVE_DATA = True

# %%
# fill in the fields below only if you are going to use live-data
CACHE_NAME = 'default.json' # the file name you want to cache the data to. The name is suggested to have ".json" at the end
DURATION = 'D' # type 'H', 'D', 'W', or 'M' for feeds in past hour, day, week, or month
MAGNITUDE = 1 # type 1, 2, 3, 4, or 5 for earthquakes that are significant, 4.5+, 2.5+, 1.0+, or all

# %%
# fill in the field below only if you are going to read data from file.
FILE_NAME = 'default.json' # the full name of the file you want to read from. It has to be in the same directory as the code.

# %% [markdown]
# ## Part 1: Data Curation: Produce the data frame for visualization

# %% [markdown]
# Import modules:

# %%
import IPython.core.display
import urllib
from pandas import read_csv
import csv
import json
import time
import re

# %% [markdown]
# Set all the global variabes:

# %%
data_json = None # the original file from url
data_csv = None # a intermediate file
data_cleaned = None # the final file for visualization
# some keys in Json we are going to use
FEATURE = 'features'
PROP = 'properties'
GEO = 'geometry'
COORD = 'coordinates'
PLACE = 'place'
# all the fields we are interested in
SRC = 'net'
ID = 'code'
TIME = 'time'
LON = 'longitude'
LAT = 'latitude'
DEP = 'depth'
MAG = 'mag'
NST = 'nst'
REGION = 'region'
DISTANCE = 'distance'
DIRECTION = 'direction'
# all urls
# 'H', 'D', 'W', or 'M' for feeds in past hour, day, week, or month
# 1, 2, 3, 4, or 5 for earthquakes that are significant, 4.5+, 2.5+, 1.0+, or all
URLs = {'H':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_hour.geojson',
             4 : 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_hour.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_hour.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_hour.geojson'},
        'D':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_day.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.geojson'},
        'W':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_week.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_week.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson'},
        'M':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_month.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_month.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson'}
        }

# %% [markdown]
# Function for getting live data and cache it:

# %%
def getLiveData():
    url = URLs[DURATION][MAGNITUDE] # the url depending on user input
    global data_json
    data_json = json.loads(urllib.urlopen(url).read()) # read in json
    with open(CACHE_NAME, 'w') as outfile:
      json.dump(data_json, outfile) # cache the data depending on user input

# %% [markdown]
# Function for getting data from file:

# %%
def readFromFile():
    global data_json
    data_json = json.loads(open(FILE_NAME, 'r').read()) # read in the cache depending on user input

# %% [markdown]
# Function for parsing the time in Json to desired format:

# %%
def parseTime(timeSinceEpoch):
    dayTime = time.strftime('%A, %B %d, %Y %H:%M:%S UTC', time.gmtime(timeSinceEpoch/1000)) 
    # to [weekday, month day, year hour:minute:second timeZone]
    return dayTime

# %% [markdown]
# Function for parsing place to desired format:

# %%
def parsePlace(place):
    match = re.match('(.+km) ([NEWS]+) of (.*)', place) # to (distance, direcion, region)
    if match:
        return (match.group(1), match.group(2), match.group(3))
    else:
        return ('NA', 'NA', place) # put everything to region if it is not of the desired format

# %% [markdown]
# Function for parsing the Json file to [{Key:Value....},{Key:Value...},...]:

# %%
def parseData():
    global data_csv
    data_csv = [] # representing a row
    for feature in data_json[FEATURE]: # add the fields to row
        dataRow = {}
        prop = feature[PROP]
        dataRow[MAG] = prop[MAG]
        placeInfo = parsePlace(prop[PLACE])
        dataRow[DISTANCE] = placeInfo[0]
        dataRow[DIRECTION] = placeInfo[1]
        dataRow[REGION] = placeInfo[2]
        dataRow[TIME] = parseTime(prop[TIME])
        dataRow[SRC] = prop[SRC]
        dataRow[ID] = prop[ID]
        dataRow[NST] = prop[NST]
        coord = feature[GEO][COORD]
        dataRow[LON] = coord[0]
        dataRow[LAT] = coord[1]
        dataRow[DEP] = coord[2]
        data_csv.append(dataRow) # add the row to list

# %% [markdown]
# Function to produce the Pandas data frame:

# %%
def getCleanedData(): # kind of a hack. convert it to csv first, then to pandas data frame using read_csv
    names = [SRC, ID, TIME, LAT, LON, MAG, DEP, NST, REGION, DISTANCE, DIRECTION]
    f = open('tem.csv', 'w')
    dict_writer = csv.DictWriter(f, names, restval='NA')
    dict_writer.writeheader()
    dict_writer.writerows(data_csv)
    f.close()
    global data_cleaned
    data_cleaned = read_csv('tem.csv')

# %% [markdown]
# ### The 'main' function:

# %%
if LIVE_DATA: # access live data and save locally
    getLiveData()
else: # read from file
    readFromFile()
parseData()
getCleanedData()

# %% [markdown]
# ### What the data frame look like:

# %%
data_cleaned[0:10]
# Out:
#   net      code                                    time  latitude  longitude  \
# 0  ci  11382002  Tuesday, October 22, 2013 06:57:06 UTC   34.4283  -117.7307
# 1  ak  10828094  Tuesday, October 22, 2013 06:56:21 UTC   64.4525  -149.5024
# 2  ak  10828090  Tuesday, October 22, 2013 06:43:20 UTC   63.6085  -150.6746
# 3  ak  10828088  Tuesday, October 22, 2013 06:32:44 UTC   64.8312  -148.6486
# 4  nc  72092691  Tuesday, October 22, 2013 06:21:10 UTC   39.5962  -123.0648
# 5  nc  72092686  Tuesday, October 22, 2013 06:19:11 UTC   37.5283  -118.8252
# 6  nc  72092681  Tuesday, October 22, 2013 06:18:18 UTC   38.8390  -122.8292
# 7  nc  72092671  Tuesday, October 22, 2013 06:06:11 UTC   38.8107  -122.8115
# 8  us  b000ki9y  Tuesday, October 22, 2013 05:40:43 UTC    5.0667    96.0306
# 9  nc  72092651  Tuesday, October 22, 2013 05:37:03 UTC   37.5625  -118.4695
#
#    mag  depth  nst                               region distance direction
# 0  1.1   8.10   17              Pinon Hills, California      7km         W
# 1  1.0  15.90  NaN                 North Nenana, Alaska     23km        SW
# 2  1.6  12.70  NaN                        Healy, Alaska     88km       WSW
# 3  0.5  15.00  NaN                        Ester, Alaska     30km         W
# 4  1.9   6.50  NaN                   Covelo, California     26km        SE
# 5  1.2   6.60  NaN            Mammoth Lakes, California     18km        SE
# 6  0.7   2.60  NaN                     Cobb, California      9km       WNW
# 7  0.6   2.50  NaN              The Geysers, California      6km        NW
# 8  5.3  48.34  NaN                  Reuleuet, Indonesia     32km       WSW
# 9  1.8  11.30  NaN  Dixon Lane-Meadow Creek, California     19km       NNW

# %% [markdown]
# ### Example for doing subset:

# %%
data_cleaned[data_cleaned[REGION] == 'The Geysers, California']
# Out:
#     net      code                                    time  latitude  \
# 7    nc  72092671  Tuesday, October 22, 2013 06:06:11 UTC   38.8107
# 15   nc  72092641  Tuesday, October 22, 2013 04:48:11 UTC   38.8117
# 22   nc  72092626  Tuesday, October 22, 2013 03:45:23 UTC   38.8240
# 46   nc  72092561  Tuesday, October 22, 2013 00:26:42 UTC   38.8310
# 61   nc  72092516   Monday, October 21, 2013 22:15:14 UTC   38.7897
# 70   nc  72092466   Monday, October 21, 2013 21:25:30 UTC   38.7703
# 79   nc  72092426   Monday, October 21, 2013 20:41:40 UTC   38.7590
# 110  nc  72092171   Monday, October 21, 2013 16:13:14 UTC   38.7727
# 130  nc  72092136   Monday, October 21, 2013 13:50:55 UTC   38.7913
# 133  nc  72092116   Monday, October 21, 2013 13:24:02 UTC   38.8252
# 137  nc  72092111   Monday, October 21, 2013 13:02:15 UTC   38.8230
# 144  nc  72092101   Monday, October 21, 2013 12:37:10 UTC   38.8155
# 159  nc  72092086   Monday, October 21, 2013 11:17:59 UTC   38.8092
# 176  nc  72092051   Monday, October 21, 2013 09:39:32 UTC   38.8085
# 182  nc  72092021   Monday, October 21, 2013 08:57:56 UTC   38.8182
#
#      longitude  mag  depth  nst                   region distance direction
# 7    -122.8115  0.6    2.5  NaN  The Geysers, California      6km        NW
# 15   -122.8123  0.9    3.4  NaN  The Geysers, California      6km        NW
# 22   -122.8053  0.8    3.1  NaN  The Geysers, California      6km        NW
# 46   -122.8642  0.9    2.8  NaN  The Geysers, California     11km       WNW
# 61   -122.7637  1.3    2.4  NaN  The Geysers, California      1km       NNW
# 70   -122.7467  0.6    2.3  NaN  The Geysers, California      1km        SE
# 79   -122.7267  0.8    2.5  NaN  The Geysers, California      3km        SE
# 110  -122.7242  0.7    2.7  NaN  The Geysers, California      2km         E
# 130  -122.7635  0.9    2.7  NaN  The Geysers, California      1km       NNW
# 133  -122.8047  0.9    3.1  NaN  The Geysers, California      6km        NW
# 137  -122.8063  1.2    3.3  NaN  The Geysers, California      6km        NW
# 144  -122.7972  0.8    1.6  NaN  The Geysers, California      5km        NW
# 159  -122.7920  1.0    1.2  NaN  The Geysers, California      4km        NW
# 176  -122.8130  1.4    2.3  NaN  The Geysers, California      6km        NW
# 182  -122.7977  0.9    2.8  NaN  The Geysers, California      5km        NW

# %% [markdown]
# ## Part 2: Data Visualization

# %%
alaska = data_cleaned[data_cleaned.net == 'ak']
alaska
# Out:
#     net      code                                    time  latitude  \
# 1    ak  10828094  Tuesday, October 22, 2013 06:56:21 UTC   64.4525
# 2    ak  10828090  Tuesday, October 22, 2013 06:43:20 UTC   63.6085
# 3    ak  10828088  Tuesday, October 22, 2013 06:32:44 UTC   64.8312
# 19   ak  10828062  Tuesday, October 22, 2013 04:32:36 UTC   64.2733
# 21   ak  10828056  Tuesday, October 22, 2013 04:05:49 UTC   62.1741
# 23   ak  10828050  Tuesday, October 22, 2013 03:39:22 UTC   60.1409
# 25   ak  10828043  Tuesday, October 22, 2013 03:29:40 UTC   61.7538
# 30   ak  10828028  Tuesday, October 22, 2013 02:31:34 UTC   63.4380
# 31   ak  10828024  Tuesday, October 22, 2013 02:22:36 UTC   61.3047
# 37   ak  10828014  Tuesday, October 22, 2013 01:31:08 UTC   62.1323
# 38   ak  10828009  Tuesday, October 22, 2013 01:26:50 UTC   62.3700
# 54   ak  10827963   Monday, October 21, 2013 23:02:43 UTC   64.9595
# 59   ak  10827941   Monday, October 21, 2013 22:32:10 UTC   61.6907
# 62   ak  10827917   Monday, October 21, 2013 22:09:41 UTC   62.5843
# 68   ak  10827903   Monday, October 21, 2013 21:41:31 UTC   63.6023
# 69   ak  10827897   Monday, October 21, 2013 21:32:21 UTC   61.0663
# 71   ak  10827891   Monday, October 21, 2013 21:18:18 UTC   62.9681
# 72   ak  10827882   Monday, October 21, 2013 21:10:59 UTC   63.2788
# 78   ak  10827813   Monday, October 21, 2013 20:47:11 UTC   63.6846
# 85   ak  10827787   Monday, October 21, 2013 20:00:39 UTC   63.9307
# 93   ak  10827769   Monday, October 21, 2013 18:51:53 UTC   61.6603
# 98   ak  10827671   Monday, October 21, 2013 18:36:21 UTC   63.5178
# 101  ak  10827632   Monday, October 21, 2013 17:23:07 UTC   61.3980
# 113  ak  10827601   Monday, October 21, 2013 15:50:28 UTC   59.3193
# 114  ak  10827597   Monday, October 21, 2013 15:22:40 UTC   62.9852
# 116  ak  10827593   Monday, October 21, 2013 15:07:26 UTC   63.5271
# 121  ak  10827589   Monday, October 21, 2013 14:39:16 UTC   63.0226
# 124  ak  10827583   Monday, October 21, 2013 14:22:08 UTC   63.1842
# 125  ak  10827579   Monday, October 21, 2013 14:18:43 UTC   60.1087
# 126  ak  10827578   Monday, October 21, 2013 14:16:31 UTC   61.5532
# 128  ak  10827570   Monday, October 21, 2013 13:57:16 UTC   59.9498
# 136  ak  10827565   Monday, October 21, 2013 13:02:59 UTC   54.6820
# 139  ak  10827560   Monday, October 21, 2013 12:52:11 UTC   63.4107
# 140  ak  10827559   Monday, October 21, 2013 12:50:34 UTC   63.5112
# 143  ak  10827553   Monday, October 21, 2013 12:40:25 UTC   63.2512
# 161  ak  10827534   Monday, October 21, 2013 11:09:46 UTC   62.6279
# 163  ak  10827529   Monday, October 21, 2013 11:02:35 UTC   62.0957
# 164  ak  10827524   Monday, October 21, 2013 10:58:57 UTC   60.6485
# 166  ak  10827523   Monday, October 21, 2013 10:55:31 UTC   62.3652
# 168  ak  10827519   Monday, October 21, 2013 10:50:43 UTC   62.7649
# 170  ak  10827515   Monday, October 21, 2013 10:44:31 UTC   60.8923
# 173  ak  10827508   Monday, October 21, 2013 10:11:50 UTC   63.4260
# 178  ak  10827501   Monday, October 21, 2013 09:29:35 UTC   60.0256
# 188  ak  10827489   Monday, October 21, 2013 08:19:49 UTC   62.7584
#
#      longitude  mag  depth  nst                   region distance direction
# 1    -149.5024  1.0   15.9  NaN     North Nenana, Alaska     23km        SW
# 2    -150.6746  1.6   12.7  NaN            Healy, Alaska     88km       WSW
# 3    -148.6486  0.5   15.0  NaN            Ester, Alaska     30km         W
# 19   -148.5109  2.1    0.2  NaN     North Nenana, Alaska     44km        SE
# 21   -145.5048  1.4   18.8  NaN       Glennallen, Alaska      7km       NNE
# 23   -151.9901  1.5   41.9  NaN     Anchor Point, Alaska     41km       NNW
# 25   -151.7148  2.1   97.8  NaN           Willow, Alaska     88km         W
# 30   -147.6322  2.4    3.4  NaN         Cantwell, Alaska     66km         E
# 31   -151.3024  1.0   58.0  NaN          Nikiski, Alaska     68km         N
# 37   -149.6052  1.2   41.7  NaN                Y, Alaska     13km       ESE
# 38   -152.3915  2.3    5.2  NaN        Talkeetna, Alaska    118km         W
# 54   -147.3349  1.5    0.1  NaN           Badger, Alaska     20km       NNE
# 59   -149.5996  1.7   29.6  NaN     Meadow Lakes, Alaska      7km         N
# 62   -148.9891  1.6   53.3  NaN                Y, Alaska     64km        NE
# 68   -149.3687  1.2  102.4  NaN         Cantwell, Alaska     31km        NW
# 69   -147.5281  1.5    1.9  NaN           Valdez, Alaska     64km         W
# 71   -148.2999  0.0    6.8  NaN         Cantwell, Alaska     57km        SE
# 72   -151.2220  1.4    6.6  NaN         Cantwell, Alaska    114km         W
# 78   -149.0159  1.2  100.0  NaN            Healy, Alaska     19km         S
# 85   -148.7912  2.3    0.0  NaN            Healy, Alaska     11km        NE
# 93   -150.9863  1.6   64.6  NaN           Willow, Alaska     51km         W
# 98   -151.0609  0.6    0.1    4         Cantwell, Alaska    106km         W
# 101  -146.6109  3.0   19.4  NaN           Valdez, Alaska     32km       NNW
# 113  -153.7175  2.8  100.0  NaN      Old Iliamna, Alaska     83km        SE
# 114  -148.1289  0.6    4.1  NaN         Cantwell, Alaska     61km        SE
# 116  -152.4403  1.6    1.0    7          McGrath, Alaska    170km       ENE
# 121  -149.5829  0.9   38.9  NaN         Cantwell, Alaska     51km        SW
# 124  -148.2605  0.3   10.4  NaN         Cantwell, Alaska     41km       ESE
# 125  -153.3140  0.9   10.8  NaN  Redoubt Volcano, Alaska     52km        SW
# 126  -149.8120  1.2   36.0  NaN         Big Lake, Alaska      8km       ENE
# 128  -152.9990  3.0  100.0   41  Redoubt Volcano, Alaska     61km       SSW
# 136  -161.0824  3.3    6.9  NaN       Sand Point, Alaska     81km       SSW
# 139  -151.7796  1.1    7.0  NaN         Cantwell, Alaska    141km         W
# 140  -147.7520  1.1    1.6  NaN         Cantwell, Alaska     61km       ENE
# 143  -151.2422  1.3   10.4  NaN         Cantwell, Alaska    115km         W
# 161  -151.2552  1.1   58.5  NaN        Talkeetna, Alaska     68km       WNW
# 163  -151.6931  1.8   98.1  NaN        Talkeetna, Alaska     86km       WSW
# 164  -151.6728  1.3   78.0  NaN          Nikiski, Alaska     21km       WSW
# 166  -149.0792  1.0   46.9   11                Y, Alaska     46km       ENE
# 168  -150.8710  1.2   31.0  NaN        Talkeetna, Alaska     62km        NW
# 170  -140.1339  1.8    0.0   19  Haines Junction, Canada    143km         W
# 173  -151.2624  1.4   10.3   10         Cantwell, Alaska    115km         W
# 178  -141.4751  1.4   11.6  NaN    Cape Yakataga, Alaska     53km         E
# 188  -150.7476  1.1   89.2  NaN        Talkeetna, Alaska     58km        NW

# %%
### Using Folium
import folium
from math import log

def map_quakes(quakes):
    # quakes is a data frame
    biggestQuake = quakes[quakes.mag == max(quakes.mag)]
    biggestQuake = biggestQuake[biggestQuake.index == min(biggestQuake.index)]
    quakes_map = folium.Map(location=[float(biggestQuake.latitude), float(biggestQuake.longitude)],  width=500, height = 300, zoom_start = 6) # centering on largest quake
    for index, quake in quakes.iterrows(): # iterating through each quake in the data frame
        message = 'This was a magnitude ' + str(quake['mag']) + ' quake that occured on ' + str(quake['time']) + ' at ' + str(quake['region'])
        quakes_map.circle_marker(location = [quake['latitude'], quake['longitude']], popup=message, radius = 5000 * (1 + int(quake['mag'])), line_color='#3186cc',
                    fill_color='#3186cc') # puts a marker on the map for each quake, with a cooresponding description
    quakes_map.create_map(path='quakes.html')

# %%
map_quakes(alaska)
