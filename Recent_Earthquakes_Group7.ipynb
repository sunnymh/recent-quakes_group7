# %% [markdown]
# # Recent Earthquakes: Group 7

# %% [markdown]
# ## Division of work:

# %% [markdown]
# He Ma: data curation
# Carl Shan: data visualization
# Alyssa Parker:?
# Vincent Canlas:?

# %% [markdown]
# ## Part 0: User Input:

# %% [markdown]
# **This section is for user configuration:**
# **Please check they are correct before running the code**

# %%
# Decide whether to use live data or read from file. Modify 2nd and 3rd cell accordingly.
LIVE_DATA = True

# %%
# fill in the fields below only if you are going to use live-data
CACHE_NAME = 'default.json' # the file name you want to cache the data to. The name is suggested to have ".json" at the end
DURATION = 'D' # type 'H', 'D', 'W', or 'M' for feeds in past hour, day, week, or month
MAGNITUDE = 1 # type 1, 2, 3, 4, or 5 for earthquakes that are significant, 4.5+, 2.5+, 1.0+, or all

# %%
# fill in the field below only if you are going to read data from file.
FILE_NAME = 'default.json' # the full name of the file you want to read from. It has to be in the same directory as the code.

# %% [markdown]
# ## Part 1: Data Curation: Produce the data frame for visualization

# %% [markdown]
# Import modules:

# %%
import IPython.core.display
import urllib
from pandas import read_csv
import csv
import json
import time
import re

# %% [markdown]
# Set all the global variabes:

# %%
data_json = None # the original file from url
data_csv = None # a intermediate file
data_cleaned = None # the final file for visualization
# some keys in Json we are going to use
FEATURE = 'features'
PROP = 'properties'
GEO = 'geometry'
COORD = 'coordinates'
PLACE = 'place'
# all the fields we are interested in
SRC = 'net'
ID = 'code'
TIME = 'time'
LON = 'longitude'
LAT = 'latitude'
DEP = 'depth'
MAG = 'mag'
NST = 'nst'
REGION = 'region'
DISTANCE = 'distance'
DIRECTION = 'direction'
# all urls
# 'H', 'D', 'W', or 'M' for feeds in past hour, day, week, or month
# 1, 2, 3, 4, or 5 for earthquakes that are significant, 4.5+, 2.5+, 1.0+, or all
URLs = {'H':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_hour.geojson',
             4 : 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_hour.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_hour.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_hour.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_hour.geojson'},
        'D':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_day.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.geojson'},
        'W':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_week.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_week.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson'},
        'M':{5: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_month.geojson',
             4: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_month.geojson',
             3: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.geojson',
             2: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_month.geojson',
             1: 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson'}
        }

# %% [markdown]
# Function for getting live data and cache it:

# %%
def getLiveData():
    url = URLs[DURATION][MAGNITUDE] # the url depending on user input
    global data_json
    data_json = json.loads(urllib.urlopen(url).read()) # read in json
    with open(CACHE_NAME, 'w') as outfile:
      json.dump(data_json, outfile) # cache the data depending on user input

# %% [markdown]
# Function for getting data from file:

# %%
def readFromFile():
    global data_json
    data_json = json.loads(open(FILE_NAME, 'r').read()) # read in the cache depending on user input

# %% [markdown]
# Function for parsing the time in Json to desired format:

# %%
def parseTime(timeSinceEpoch):
    dayTime = time.strftime('%A, %B %d, %Y %H:%M:%S UTC', time.gmtime(timeSinceEpoch/1000)) 
    # to [weekday, month day, year hour:minute:second timeZone]
    return dayTime

# %% [markdown]
# Function for parsing place to desired format:

# %%
def parsePlace(place):
    match = re.match('(.+km) ([NEWS]+) of (.*)', place) # to (distance, direcion, region)
    if match:
        return (match.group(1), match.group(2), match.group(3))
    else:
        return ('NA', 'NA', place) # put everything to region if it is not of the desired format

# %% [markdown]
# Function for parsing the Json file to [{Key:Value....},{Key:Value...},...]:

# %%
def parseData():
    global data_csv
    data_csv = [] # representing a row
    for feature in data_json[FEATURE]: # add the fields to row
        dataRow = {}
        prop = feature[PROP]
        dataRow[MAG] = prop[MAG]
        placeInfo = parsePlace(prop[PLACE])
        dataRow[DISTANCE] = placeInfo[0]
        dataRow[DIRECTION] = placeInfo[1]
        dataRow[REGION] = placeInfo[2]
        dataRow[TIME] = parseTime(prop[TIME])
        dataRow[SRC] = prop[SRC]
        dataRow[ID] = prop[ID]
        dataRow[NST] = prop[NST]
        coord = feature[GEO][COORD]
        dataRow[LON] = coord[0]
        dataRow[LAT] = coord[1]
        dataRow[DEP] = coord[2]
        data_csv.append(dataRow) # add the row to list

# %% [markdown]
# Function to produce the Pandas data frame:

# %%
def getCleanedData(): # kind of a hack. convert it to csv first, then to pandas data frame using read_csv
    names = [SRC, ID, TIME, LAT, LON, MAG, DEP, NST, REGION, DISTANCE, DIRECTION]
    f = open('tem.csv', 'w')
    dict_writer = csv.DictWriter(f, names, restval='NA')
    dict_writer.writeheader()
    dict_writer.writerows(data_csv)
    f.close()
    global data_cleaned
    data_cleaned = read_csv('tem.csv')

# %% [markdown]
# ### The 'main' function:

# %%
if LIVE_DATA: # access live data and save locally
    getLiveData()
else: # read from file
    readFromFile()
parseData()
getCleanedData()

# %% [markdown]
# ### What the data frame look like:

# %%
data_cleaned[0:10]
# Out:
#   net      code                                   time  latitude  longitude  \
# 0  nc  72091196  Sunday, October 20, 2013 06:02:39 UTC   38.7603  -122.8472
# 1  nc  72091191  Sunday, October 20, 2013 06:00:29 UTC   36.3077  -120.8717
# 2  nc  72091181  Sunday, October 20, 2013 05:54:39 UTC   38.7882  -122.7273
# 3  nc  72091176  Sunday, October 20, 2013 05:53:56 UTC   38.8088  -122.8117
# 4  nc  72091171  Sunday, October 20, 2013 05:53:34 UTC   38.7645  -122.8470
# 5  nc  72091166  Sunday, October 20, 2013 05:50:37 UTC   38.7665  -122.8458
# 6  nc  72091156  Sunday, October 20, 2013 05:50:26 UTC   38.7622  -122.8452
# 7  nc  72091161  Sunday, October 20, 2013 05:49:25 UTC   38.7542  -122.7387
# 8  us  b000khii  Sunday, October 20, 2013 05:38:18 UTC   19.4923   -92.1161
# 9  hv  60579686  Sunday, October 20, 2013 05:25:41 UTC   19.9262  -156.1603
#
#    mag  depth  nst                     region distance direction
# 0  1.3   4.20  NaN    The Geysers, California      8km       WSW
# 1  2.0   4.70  NaN      King City, California     25km       ENE
# 2  0.9   2.60  NaN    The Geysers, California      2km       ENE
# 3  1.4   1.90  NaN    The Geysers, California      5km        NW
# 4  1.2   4.50  NaN    The Geysers, California      8km         W
# 5  1.0   4.40  NaN    The Geysers, California      7km         W
# 6  1.5   4.30  NaN    The Geysers, California      7km       WSW
# 7  0.5   3.70  NaN    The Geysers, California      2km       SSE
# 8  4.2  13.93  NaN  Ciudad del Carmen, Mexico     99km       NNW
# 9  3.0  10.30  NaN             Kalaoa, Hawaii     28km        NW

# %% [markdown]
# ### Example for doing subset:

# %%
data_cleaned[data_cleaned[REGION] == 'The Geysers, California']
# Out:
#     net      code                                     time  latitude  \
# 0    nc  72091196    Sunday, October 20, 2013 06:02:39 UTC   38.7603
# 2    nc  72091181    Sunday, October 20, 2013 05:54:39 UTC   38.7882
# 3    nc  72091176    Sunday, October 20, 2013 05:53:56 UTC   38.8088
# 4    nc  72091171    Sunday, October 20, 2013 05:53:34 UTC   38.7645
# 5    nc  72091166    Sunday, October 20, 2013 05:50:37 UTC   38.7665
# 6    nc  72091156    Sunday, October 20, 2013 05:50:26 UTC   38.7622
# 7    nc  72091161    Sunday, October 20, 2013 05:49:25 UTC   38.7542
# 16   nc  72091131    Sunday, October 20, 2013 04:20:42 UTC   38.8313
# 20   nc  72091111    Sunday, October 20, 2013 03:52:56 UTC   38.7552
# 25   nc  72091096    Sunday, October 20, 2013 02:23:43 UTC   38.7888
# 26   nc  72091091    Sunday, October 20, 2013 02:23:36 UTC   38.7910
# 35   nc  72091036    Sunday, October 20, 2013 00:52:55 UTC   38.8135
# 37   nc  72091026    Sunday, October 20, 2013 00:35:18 UTC   38.7872
# 63   nc  72090971  Saturday, October 19, 2013 20:46:43 UTC   38.7858
# 66   nc  72090956  Saturday, October 19, 2013 20:25:59 UTC   38.8157
# 69   nc  72090946  Saturday, October 19, 2013 20:08:44 UTC   38.8232
# 73   nc  72090926  Saturday, October 19, 2013 19:21:36 UTC   38.8082
# 74   nc  72090921  Saturday, October 19, 2013 18:31:30 UTC   38.7863
# 76   nc  72090901  Saturday, October 19, 2013 18:05:07 UTC   38.7898
# 86   nc  72090851  Saturday, October 19, 2013 16:12:49 UTC   38.8140
# 110  nc  72090756  Saturday, October 19, 2013 11:39:01 UTC   38.7890
# 124  nc  72090706  Saturday, October 19, 2013 09:20:32 UTC   38.8170
# 134  nc  72090676  Saturday, October 19, 2013 07:29:08 UTC   38.8103
#
#      longitude  mag  depth  nst                   region distance direction
# 0    -122.8472  1.3    4.2  NaN  The Geysers, California      8km       WSW
# 2    -122.7273  0.9    2.6  NaN  The Geysers, California      2km       ENE
# 3    -122.8117  1.4    1.9  NaN  The Geysers, California      5km        NW
# 4    -122.8470  1.2    4.5  NaN  The Geysers, California      8km         W
# 5    -122.8458  1.0    4.4  NaN  The Geysers, California      7km         W
# 6    -122.8452  1.5    4.3  NaN  The Geysers, California      7km       WSW
# 7    -122.7387  0.5    3.7  NaN  The Geysers, California      2km       SSE
# 16   -122.8552  0.6    2.7  NaN  The Geysers, California     10km        NW
# 20   -122.7230  0.5    2.6  NaN  The Geysers, California      3km        SE
# 25   -122.7290  1.1    2.7  NaN  The Geysers, California      2km       ENE
# 26   -122.7298  1.8    2.4  NaN  The Geysers, California      2km       ENE
# 35   -122.8235  0.6    5.1  NaN  The Geysers, California      7km        NW
# 37   -122.7275  1.6    2.3  NaN  The Geysers, California      2km       ENE
# 63   -122.7645  0.6    1.9  NaN  The Geysers, California      1km        NW
# 66   -122.7940  0.6    2.8  NaN  The Geysers, California      5km        NW
# 69   -122.8063  1.8    1.0  NaN  The Geysers, California      6km        NW
# 73   -122.8147  1.1    2.6  NaN  The Geysers, California      6km        NW
# 74   -122.7638  1.2    2.0  NaN  The Geysers, California      1km       NNW
# 76   -122.7387  1.8    2.8  NaN  The Geysers, California      2km        NE
# 86   -122.8253  1.4    3.0  NaN  The Geysers, California      7km        NW
# 110  -122.7627  1.1    2.4  NaN  The Geysers, California      1km       NNW
# 124  -122.8168  1.2    2.7  NaN  The Geysers, California      6km        NW
# 134  -122.7883  0.5    3.0  NaN  The Geysers, California      4km        NW

# %% [markdown]
# ## Part 2: Data Visualization

# %%
# More code here
